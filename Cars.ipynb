# %% [markdown]
# <a href="https://colab.research.google.com/github/jonathanrao99/Book-scraping/blob/main/Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
car=pd.read_csv("CARS.csv")

# %%
print(car.shape)
# Out:
# (428, 15)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 428 entries, 0 to 427
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Make         428 non-null    object
#  1   Model        428 non-null    object
#  2   Type         428 non-null    object
#  3   Origin       428 non-null    object
#  4   DriveTrain   428 non-null    object
#  5   MSRP         428 non-null    object
#  6   Invoice      428 non-null    object
#  7   EngineSize   428 non-null    float64
#  8   Cylinders    426 non-null    float64
#  9   Horsepower   428 non-null    int64
#  10  MPG_City     428 non-null    int64
#  11  MPG_Highway  428 non-null    int64
#  12  Weight       428 non-null    int64
#  13  Wheelbase    428 non-null    int64
#  14  Length       428 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 50.3+ KB

# %%
print(car.columns)
# Out:
# Index(['Make', 'Model', 'Type', 'Origin', 'DriveTrain', 'MSRP', 'Invoice',
#        'EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway',
#        'Weight', 'Wheelbase', 'Length'],
#       dtype='object')

# %%
car.head()
# Out:
#     Make           Model   Type Origin DriveTrain     MSRP  Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945  $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820  $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990  $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195  $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755  $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0         265        17           23    4451
# 1         2.0        4.0         200        24           31    2778
# 2         2.4        4.0         200        22           29    3230
# 3         3.2        6.0         270        20           28    3575
# 4         3.5        6.0         225        18           24    3880
#
#    Wheelbase  Length
# 0        106     189
# 1        101     172
# 2        105     183
# 3        108     186
# 4        115     197

# %%
car.head(10)
# Out:
#     Make                    Model    Type  Origin DriveTrain     MSRP  \
# 0  Acura                      MDX     SUV    Asia        All  $36,945
# 1  Acura           RSX Type S 2dr   Sedan    Asia      Front  $23,820
# 2  Acura                  TSX 4dr   Sedan    Asia      Front  $26,990
# 3  Acura                   TL 4dr   Sedan    Asia      Front  $33,195
# 4  Acura               3.5 RL 4dr   Sedan    Asia      Front  $43,755
# 5  Acura  3.5 RL w/Navigation 4dr   Sedan    Asia      Front  $46,100
# 6  Acura   NSX coupe 2dr manual S  Sports    Asia       Rear  $89,765
# 7   Audi              A4 1.8T 4dr   Sedan  Europe      Front  $25,940
# 8   Audi   A41.8T convertible 2dr   Sedan  Europe      Front  $35,940
# 9   Audi               A4 3.0 4dr   Sedan  Europe      Front  $31,840
#
#    Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0  $33,337         3.5        6.0         265        17           23    4451
# ...

# %%
car.tail()
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# 423  $38,203         2.4        5.0         197        21           28
# 424  $40,083         2.3        5.0         242        20           26
# 425  $42,573         2.9        6.0         268        19           26
# 426  $24,641         1.9        4.0         170        22           29
# 427  $33,112         2.5        5.0         208        20           27
#
#      Weight  Wheelbase  Length
# 423    3450        105     186
# 424    3450        105     186
# ...

# %%
cars=car.drop(['Length','Weight'],axis=1)

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars=cars.drop_duplicates(keep='first')

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.isnull().sum()
# Out:
# Make           0
# Model          0
# Type           0
# Origin         0
# DriveTrain     0
# MSRP           0
# Invoice        0
# EngineSize     0
# Cylinders      2
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Wheelbase      0
# dtype: int64

# %%
cars.dropna(inplace=True)

# %%
cars
# Out:
#       Make                    Model   Type  Origin DriveTrain     MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...      ...
# 423  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 424  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 425  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 426  Volvo                      V40  Wagon  Europe      Front  $26,135
# 427  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#      Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
cars.iloc[[0,2,4], [1,3,5]]
# Out:
#         Model Origin     MSRP
# 0         MDX   Asia  $36,945
# 2     TSX 4dr   Asia  $26,990
# 4  3.5 RL 4dr   Asia  $43,755

# %%
x=cars.iloc[0:5,8]
x
# Out:
# 0    6.0
# 1    4.0
# 2    4.0
# 3    6.0
# 4    6.0
# Name: Cylinders, dtype: float64

# %%
x=cars.loc[0:5,'MPG_City']
x
# Out:
# 0    17
# 1    24
# 2    22
# 3    20
# 4    18
# 5    18
# Name: MPG_City, dtype: int64

# %%
cars1=car[['EngineSize', 'Cylinders', 'Horsepower', 'MPG_City', 'MPG_Highway','Weight', 'Wheelbase', 'Length']]
cars1
# Out:
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0           3.5        6.0         265        17           23    4451
# 1           2.0        4.0         200        24           31    2778
# 2           2.4        4.0         200        22           29    3230
# 3           3.2        6.0         270        20           28    3575
# 4           3.5        6.0         225        18           24    3880
# ..          ...        ...         ...       ...          ...     ...
# 423         2.4        5.0         197        21           28    3450
# 424         2.3        5.0         242        20           26    3450
# 425         2.9        6.0         268        19           26    3653
# 426         1.9        4.0         170        22           29    2822
# 427         2.5        5.0         208        20           27    3823
#
#      Wheelbase  Length
# 0          106     189
# 1          101     172
# 2          105     183
# 3          108     186
# ...

# %%
cars1 = cars.select_dtypes(include=['float64', 'int64']) 
cars1
# Out:
#      EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Wheelbase
# 0           3.5        6.0         265        17           23        106
# 1           2.0        4.0         200        24           31        101
# 2           2.4        4.0         200        22           29        105
# 3           3.2        6.0         270        20           28        108
# 4           3.5        6.0         225        18           24        115
# ..          ...        ...         ...       ...          ...        ...
# 423         2.4        5.0         197        21           28        105
# 424         2.3        5.0         242        20           26        105
# 425         2.9        6.0         268        19           26        110
# 426         1.9        4.0         170        22           29        101
# 427         2.5        5.0         208        20           27        109
#
# [426 rows x 6 columns]

# %%
cars.describe()
# Out:
#        EngineSize   Cylinders  Horsepower    MPG_City  MPG_Highway   Wheelbase
# count  426.000000  426.000000  426.000000  426.000000   426.000000  426.000000
# mean     3.205634    5.807512  215.877934   20.070423    26.854460  108.164319
# std      1.103520    1.558443   71.991040    5.248616     5.752335    8.330030
# min      1.400000    3.000000   73.000000   10.000000    12.000000   89.000000
# 25%      2.400000    4.000000  165.000000   17.000000    24.000000  103.000000
# 50%      3.000000    6.000000  210.000000   19.000000    26.000000  107.000000
# 75%      3.900000    6.000000  255.000000   21.750000    29.000000  112.000000
# max      8.300000   12.000000  500.000000   60.000000    66.000000  144.000000

# %%
cars.corr(method ='pearson')
# Out:
#              EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# EngineSize     1.000000   0.908002    0.793250 -0.717860    -0.725901
# Cylinders      0.908002   1.000000    0.810341 -0.684402    -0.676100
# Horsepower     0.793250   0.810341    1.000000 -0.677034    -0.647425
# MPG_City      -0.717860  -0.684402   -0.677034  1.000000     0.940993
# MPG_Highway   -0.725901  -0.676100   -0.647425  0.940993     1.000000
# Wheelbase      0.638947   0.546730    0.387561 -0.508029    -0.525457
#
#              Wheelbase
# EngineSize    0.638947
# Cylinders     0.546730
# Horsepower    0.387561
# MPG_City     -0.508029
# MPG_Highway  -0.525457
# Wheelbase     1.000000

# %%
cars.corr(method ='pearson')['MPG_City']
# Out:
# EngineSize    -0.717860
# Cylinders     -0.684402
# Horsepower    -0.677034
# MPG_City       1.000000
# MPG_Highway    0.940993
# Wheelbase     -0.508029
# Name: MPG_City, dtype: float64

# %%
sns.displot (data=cars, x='MPG_City', bins=10, kde=True, color='blue')

# %%
sns.regplot (x='Length', y='MPG_City', data=car)

# %%
box1=sns.boxplot (x='Type', y='MPG_City', data=car)

# %%
box2=sns.boxplot (x='Origin', y='MPG_City', data=car)

# %%
sns.pairplot(cars, hue='Origin')
